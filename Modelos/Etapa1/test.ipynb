# %%
# !tensorflowjs_converter \
  --input_format=tf_saved_model \
  /Users/claracelestechavezcotrina/Documents/Tesis-Mammo/Entrenamientos/saved_model_format  \
  /Users/claracelestechavezcotrina/Documents/Tesis-Mammo/Entrenamientos/tfjs_model
# Out:
# 🌲 Try https://ydf.readthedocs.io, the successor of TensorFlow Decision Forests with more features and faster training!
# /opt/miniconda3/envs/tfjs_convert/lib/python3.10/site-packages/tensorflow_hub/__init__.py:61: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1771805492.017089  141895 devices.cc:76] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA or ROCm support)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1771805492.018316  141895 single_machine.cc:374] Starting new session
